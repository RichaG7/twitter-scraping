# %%
#import dependencies 
from splinter import Browser
from bs4 import BeautifulSoup as bs
import time 
import pandas as pd
import re
import time
import numpy as np

# %%
def scrape_twitter(query, lang, start_date, end_date):
    
    browser = init_browser()
    
    #get latest tweet 
    twitter_url = f'https://twitter.com/search?q={query}%20lang:{lang}%20until:{end_date}%20since:{start_date}&src=typed_query'
    
    browser.visit(twitter_url)
    
    time.sleep(2)

    pattern = re.compile(query[0], re.IGNORECASE)

    html = browser.html
    soup = bs(html, 'html.parser')

    tweets = soup.find('span', text=pattern).text
    user_name = 
    time_stamp = 
    likes = 
    comments = 
    retweets = 

    #store data in a dictionary
    tweets = {
        'username': user_name,
        'timestamp': time_stamp,
        'tweet': tweets,
        'likes': likes,
        'comments': comments,
        'retweets': retweets
    }
        
        
    #close the browser
    browser.quit()
    
    return tweets

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

#search query
lang = "en"
query = ["Indian", "indian"] # ["asian", "Asian"]
start_date = "2019-11-01"
end_date = "2019-11-30"

#get latest tweet 
twitter_url = f'https://twitter.com/search?q={query}%20lang:{lang}%20until:{end_date}%20since:{start_date}&src=typed_query'
    
browser.visit(twitter_url)
    
time.sleep(2)

pattern = re.compile(query[0], re.IGNORECASE)

html = browser.html

soup = bs(html, 'lxml')

print(soup.prettify())
# Out:
# <html dir="ltr" lang="en" style="font-size: 15px;">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=0,viewport-fit=cover" name="viewport"/>
#   <link href="//abs.twimg.com" rel="preconnect"/>
#   <link href="//api.twitter.com" rel="preconnect"/>
#   <link href="//pbs.twimg.com" rel="preconnect"/>
#   <link href="//t.co" rel="preconnect"/>
#   <link href="//video.twimg.com" rel="preconnect"/>
#   <link href="//abs.twimg.com" rel="dns-prefetch"/>
#   <link href="//api.twitter.com" rel="dns-prefetch"/>
#   <link href="//pbs.twimg.com" rel="dns-prefetch"/>
#   <link href="//t.co" rel="dns-prefetch"/>
#   <link href="//video.twimg.com" rel="dns-prefetch"/>
#   <link as="script" crossorigin="anonymous" href="https://abs.twimg.com/responsive-web/web/polyfills.6cc90b94.js" nonce="" rel="preload"/>
# ...

# %%
test = soup.select('span', class_='css-901oao')

test_response = []

response_range = np.arange(len(test))
for position in response_range:
    print(position)
    try:
        response = test[position].text
        print(response)
        test_response = test_response.append(response)
    except:
        pass
# Out:
# 0
#
# 1
#
# 2
#
# 3
# Log in
# 4
# Log in
# 5
# Sign up
# 6
# Sign up
# 7
#
# 8
# See new Tweets
# 9
# ['Indian', 'indian'] lang:en until:2019-11-30 since:2019-11-01
# 10
#
# 11
# Top
# 12
# Latest
# 13
# People
# 14
# Photos
# 15
# Videos
# 16
# Top
# 17
# Latest
# 18
# People
# 19
# Photos
# 20
# Videos
# 21
# Department of Defense
# 22
# Department of Defense
# 23
#
# 24
# @DeptofDefense
# 25
# ·
# 26
# .
# 27
# @USMC
# 28
#  gets the job done anywhere in the world. Check out how they work side by side with
# 29
# Indian
# 30
#  allies during exercise Tiger TRIUMPH on Kakinada Beach, India.
# 31
# #KnowYourMil
# 32
#
# 33
#
# 34
#
# 35
#
# 36
# 20
# 37
# 20
# 38
# 219
# 39
# 219
# 40
# 1.1K
# 41
# 1.1K
# 42
# Al Jazeera English
# 43
# Al Jazeera English
# 44
# @AJEnglish
# 45
# ·
# 46
# This group of volunteers have come together to help provide free education for children in
# 47
# Indian
# 48
# -administered Kashmir.
# 49
# 2:35
# 50
# 2:35
# 51
# 40.7K views
# 52
# 8
# 53
# 8
# ...

# %%
test_response
